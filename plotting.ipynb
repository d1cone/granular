# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = np.loadtxt("./logs/polarizable_q=pm1", skiprows=1)
t = df[:,0]
H = df[:,1]
K = df[:,2]
U = df[:,3]

# %%
df = np.loadtxt("./logs/coulomb_q=pm1", skiprows=1)
t = df[:,0]
H = df[:,1]
K = df[:,2]
U = df[:,3]

# %%
plt.plot(t, U, label='potential energy')
plt.plot(t, K, label='kinetic energy')
plt.plot(t, H, label='total energy')
plt.legend()
plt.show()

# %%
plt.plot(t, U, label='potential energy')
plt.plot(t, K, label='kinetic energy')
plt.plot(t, H, label='total energy')
plt.legend()
plt.show()
